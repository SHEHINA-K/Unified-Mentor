# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Heart Disease data.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info
# Out:
# <bound method DataFrame.info of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.value_counts('target')
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
sns.countplot(x=df['target'])
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
cmap=sns.diverging_palette(275,150,
    s=75,
    l=50,
    n=6,
    center='light',
    as_cmap=True )
corr=df.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corr,cmap=cmap,annot=True ,square=True)
# Out:
# <Axes: >

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
#Checking The Shape of the Dataset
print('The number of rows in the dataset ',df.shape[0])
print('The number of columns in the dataset ',df.shape[1])
# Out:
# The number of rows in the dataset  1025
# The number of columns in the dataset  14

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='target', y='age', data=df)
plt.title('Comparison of Age and Target')
plt.xlabel('Target')
plt.ylabel('Age')
plt.show()

# %%
pd.crosstab(df['age'],df['target'])
# Out:
# target   0   1
# age
# 29       0   4
# 34       0   6
# 35       7   8
# 37       0   6
# 38       4   8
# 39       4  10
# 40       8   3
# 41       3  29
# 42       4  22
# 43      11  15
# 44      10  26
# 45       6  19
# 46      11  12
# 47       8  10
# 48      11  12
# 49       8   9
# 50       9  12
# 51      10  29
# 52      15  28
# 53       8  18
# 54      21  32
# 55      20  10
# 56      22  17
# 57      36  21
# 58      44  24
# 59      31  15
# 60      27  10
# 61      28   3
# 62      24  13
# 63      23   9
# 64      15  19
# 65      15  12
# 66      11  14
# 67      22   9
# 68       6   6
# 69       3   6
# 70      11   3
# 71       0  11
# 74       0   3
# 76       0   3
# 77       3   0

# %%
# Plot histograms
df.hist(figsize=(10, 8))
plt.show()

# %%
cor=df.corr()
plt.figure(figsize=(15,5))
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='target', y='sex', data=df)
plt.title('Comparison of Age and Target')
plt.xlabel('Target')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='target', y='cp', data=df)
plt.title('Comparison of CP and Target')
plt.xlabel('Target')
plt.ylabel('Age')
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
feature = ["age",'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
for i in feature:
    plt.figure(figsize=(8,8))
    sns.boxplot(x = df['target'],y=df[i] )
    sns.swarmplot(x = df['target'],y=df[i] ,color="black", alpha=0.5)
    plt.show()
# Out:
# C:\Users\WELCOME\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3370: UserWarning: 86.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\WELCOME\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3370: UserWarning: 86.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\WELCOME\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3370: UserWarning: 74.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\WELCOME\AppData\Roaming\Python\Python312\site-packages\seaborn\categorical.py:3370: UserWarning: 73.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
X=df.drop(['target'],axis=1)
y=df['target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=7)

# %%
# Scale the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report
y_pred = model.predict(X_test)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       117
#            1       1.00      1.00      1.00       140
#
#     accuracy                           1.00       257
#    macro avg       1.00      1.00      1.00       257
# weighted avg       1.00      1.00      1.00       257
